# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, LSTM, Dense, Bidirectional

# %%
# sonnets.txt
# !gdown --id 108jAePKK4R3BVYBbYJZ32JWUwxeMg20K
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=108jAePKK4R3BVYBbYJZ32JWUwxeMg20K
# To: /content/sonnets.txt
# 100% 93.6k/93.6k [00:00<00:00, 77.6MB/s]

# %%
# Define path for file with sonnets
SONNETS_FILE = './sonnets.txt'

# Read the data
with open('./sonnets.txt') as f:
    data = f.read()

# Convert to lower case and save as a list
corpus = data.lower().split("\n")

print(f"There are {len(corpus)} lines of sonnets\n")
print(f"The first 5 lines look like this:\n")
for i in range(5):
  print(corpus[i])
# Out:
# There are 2159 lines of sonnets
#
# The first 5 lines look like this:
#
# from fairest creatures we desire increase,
# that thereby beauty's rose might never die,
# but as the riper should by time decease,
# his tender heir might bear his memory:
# but thou, contracted to thine own bright eyes,

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(corpus)
total_words = len(tokenizer.word_index) + 1

# %%
corpus[0]
# Out:
# 'from fairest creatures we desire increase,'

# %%
tokenizer.texts_to_sequences(corpus[0])
# Out:
# [[],
#  [],
#  [58],
#  [],
#  [],
#  [],
#  [17],
#  [6],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [17],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [6],
#  [],
#  [],
#  [],
#  [6],
#  [],
#  [],
#  [],
#  [],
#  [17],
#  [],
#  [],
#  []]

# %%
tokenizer.texts_to_sequences([corpus[0]])
# Out:
# [[34, 417, 877, 166, 213, 517]]

# %%
tokenizer.texts_to_sequences([corpus[0]])[0]
# Out:
# [34, 417, 877, 166, 213, 517]

# %%
def n_gram_seqs(corpus, tokenizer):
    """
    Generates a list of n-gram sequences

    Args:
        corpus (list of string): lines of texts to generate n-grams for
        tokenizer (object): an instance of the Tokenizer class containing the word-index dictionary

    Returns:
        input_sequences (list of int): the n-gram sequences for each line in the corpus
    """
    input_sequences = []

    ### START CODE HERE

    for line in corpus:
      token_list = tokenizer.texts_to_sequences([line])[0]

      for i in range(1, len(token_list)):
        # Generate subphrase
        n_gram_sequence = token_list[:i+1]
        # Append subphrase to input_sequences list
        input_sequences.append(n_gram_sequence)

    ### END CODE HERE

    return input_sequences

# %%
# Test your function with one example
first_example_sequence = n_gram_seqs([corpus[0]], tokenizer)

print("n_gram sequences for first example look like this:\n")
first_example_sequence
# Out:
# n_gram sequences for first example look like this:
# [[34, 417],
#  [34, 417, 877],
#  [34, 417, 877, 166],
#  [34, 417, 877, 166, 213],
#  [34, 417, 877, 166, 213, 517]]

# %%
# Test your function with a bigger corpus
next_3_examples_sequence = n_gram_seqs(corpus[1:4], tokenizer)

print("n_gram sequences for next 3 examples look like this:\n")
next_3_examples_sequence
# Out:
# n_gram sequences for next 3 examples look like this:
# [[8, 878],
#  [8, 878, 134],
#  [8, 878, 134, 351],
#  [8, 878, 134, 351, 102],
#  [8, 878, 134, 351, 102, 156],
#  [8, 878, 134, 351, 102, 156, 199],
#  [16, 22],
#  [16, 22, 2],
#  [16, 22, 2, 879],
#  [16, 22, 2, 879, 61],
#  [16, 22, 2, 879, 61, 30],
#  [16, 22, 2, 879, 61, 30, 48],
#  [16, 22, 2, 879, 61, 30, 48, 634],
#  [25, 311],
#  [25, 311, 635],
#  [25, 311, 635, 102],
#  [25, 311, 635, 102, 200],
#  [25, 311, 635, 102, 200, 25],
#  [25, 311, 635, 102, 200, 25, 278]]

# %% [markdown]
# Apply the `n_gram_seqs` transformation to the whole corpus and save the maximum sequence length to use it later:

# %%
# Apply the n_gram_seqs transformation to the whole corpus
input_sequences = n_gram_seqs(corpus, tokenizer)

# Save max length
max_sequence_len = max([len(x) for x in input_sequences])

print(f"n_grams of input_sequences have length: {len(input_sequences)}")
print(f"maximum length of sequences is: {max_sequence_len}")
# Out:
# n_grams of input_sequences have length: 15462
# maximum length of sequences is: 11

# %%
def pad_seqs(input_sequences, maxlen):
    """
    Pads tokenized sequences to the same length

    Args:
        input_sequences (list of int): tokenized sequences to pad
        maxlen (int): maximum length of the token sequences

    Returns:
        padded_sequences (array of int): tokenized sequences padded to the same length
    """
    ### START CODE HERE
    padded_sequences = pad_sequences(input_sequences, maxlen=maxlen, padding='pre')

    return padded_sequences
    ### END CODE HERE

# %%
# Test your function with the n_grams_seq of the first example
first_padded_seq = pad_seqs(first_example_sequence, max([len(x) for x in first_example_sequence]))
first_padded_seq
# Out:
# array([[  0,   0,   0,   0,  34, 417],
#        [  0,   0,   0,  34, 417, 877],
#        [  0,   0,  34, 417, 877, 166],
#        [  0,  34, 417, 877, 166, 213],
#        [ 34, 417, 877, 166, 213, 517]], dtype=int32)

# %%
# Test your function with the n_grams_seq of the next 3 examples
next_3_padded_seq = pad_seqs(next_3_examples_sequence, max([len(s) for s in next_3_examples_sequence]))
next_3_padded_seq
# Out:
# array([[  0,   0,   0,   0,   0,   0,   8, 878],
#        [  0,   0,   0,   0,   0,   8, 878, 134],
#        [  0,   0,   0,   0,   8, 878, 134, 351],
#        [  0,   0,   0,   8, 878, 134, 351, 102],
#        [  0,   0,   8, 878, 134, 351, 102, 156],
#        [  0,   8, 878, 134, 351, 102, 156, 199],
#        [  0,   0,   0,   0,   0,   0,  16,  22],
#        [  0,   0,   0,   0,   0,  16,  22,   2],
#        [  0,   0,   0,   0,  16,  22,   2, 879],
#        [  0,   0,   0,  16,  22,   2, 879,  61],
#        [  0,   0,  16,  22,   2, 879,  61,  30],
#        [  0,  16,  22,   2, 879,  61,  30,  48],
#        [ 16,  22,   2, 879,  61,  30,  48, 634],
#        [  0,   0,   0,   0,   0,   0,  25, 311],
#        [  0,   0,   0,   0,   0,  25, 311, 635],
#        [  0,   0,   0,   0,  25, 311, 635, 102],
#        [  0,   0,   0,  25, 311, 635, 102, 200],
#        [  0,   0,  25, 311, 635, 102, 200,  25],
#        [  0,  25, 311, 635, 102, 200,  25, 278]], dtype=int32)

# %%
# Pad the whole corpus
input_sequences = pad_seqs(input_sequences, max_sequence_len)

print(f"padded corpus has shape: {input_sequences.shape}")
# Out:
# padded corpus has shape: (15462, 11)

# %%
def features_and_labels(input_sequences, total_words):
    """
    Generates features and labels from n-grams

    Args:
        input_sequences (list of int): sequences to split features and labels from
        total_words (int): vocabulary size

    Returns:
        features, one_hot_labels (array of int, array of int): arrays of features and one-hot encoded labels
    """
    ### START CODE HERE
    features = input_sequences[:,:-1]
    labels = input_sequences[:,-1]
    one_hot_labels = to_categorical(labels, num_classes=total_words)
    ### END CODE HERE

    return features, one_hot_labels

# %%
# Test your function with the padded n_grams_seq of the first example
first_features, first_labels = features_and_labels(first_padded_seq, total_words)

print(f"labels have shape: {first_labels.shape}")
print("\nfeatures look like this:\n")
first_features
# Out:
# labels have shape: (5, 3211)
#
# features look like this:
# array([[  0,   0,   0,   0,  34],
#        [  0,   0,   0,  34, 417],
#        [  0,   0,  34, 417, 877],
#        [  0,  34, 417, 877, 166],
#        [ 34, 417, 877, 166, 213]], dtype=int32)

# %%
# Split the whole corpus
features, labels = features_and_labels(input_sequences, total_words)

print(f"features have shape: {features.shape}")
print(f"labels have shape: {labels.shape}")
# Out:
# features have shape: (15462, 10)
# labels have shape: (15462, 3211)

# %%
def create_model(total_words, max_sequence_len):
    """
    Creates a text generator model

    Args:
        total_words (int): size of the vocabulary for the Embedding layer input
        max_sequence_len (int): length of the input sequences

    Returns:
        model (tf.keras Model): the text generator model
    """
    model = Sequential()
    ### START CODE HERE
    model.add(Embedding(total_words, 100, input_length=max_sequence_len-1))
    model.add(Bidirectional(LSTM(150)))
    model.add(Dense(total_words, activation='softmax'))

    # Compile the model
    model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])

    ### END CODE HERE

    return model

# %%
# Get the untrained model
model = create_model(total_words, max_sequence_len)

# Train the model
history = model.fit(features, labels, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 484/484 [==============================] - 23s 35ms/step - loss: 6.8872 - accuracy: 0.0232
# Epoch 2/100
# 484/484 [==============================] - 14s 29ms/step - loss: 6.4275 - accuracy: 0.0317
# Epoch 3/100
# 484/484 [==============================] - 14s 30ms/step - loss: 6.1936 - accuracy: 0.0406
# Epoch 4/100
# 484/484 [==============================] - 15s 31ms/step - loss: 5.9455 - accuracy: 0.0498
# Epoch 5/100
# 484/484 [==============================] - 15s 31ms/step - loss: 5.6447 - accuracy: 0.0630
# Epoch 6/100
# 484/484 [==============================] - 15s 30ms/step - loss: 5.2972 - accuracy: 0.0733
# Epoch 7/100
# 484/484 [==============================] - 15s 31ms/step - loss: 4.9245 - accuracy: 0.0925
# Epoch 8/100
# 484/484 [==============================] - 14s 29ms/step - loss: 4.5278 - accuracy: 0.1202
# Epoch 9/100
# 484/484 [==============================] - 15s 30ms/step - loss: 4.1286 - accuracy: 0.1663
# Epoch 10/100
# 484/484 [==============================] - 14s 29ms/step - loss: 3.7369 - accuracy: 0.2297
# Epoch 11/100
# 484/484 [==============================] - 15s 31ms/step - loss: 3.3663 - accuracy: 0.2960
# Epoch 12/100
# 484/484 [==============================] - 15s 30ms/step - loss: 3.0257 - accuracy: 0.3620
# Epoch 13/100
# 484/484 [==============================] - 15s 30ms/step - loss: 2.7256 - accuracy: 0.4206
# Epoch 14/100
# 484/484 [==============================] - 14s 30ms/step - loss: 2.4553 - accuracy: 0.4750
# Epoch 15/100
# 484/484 [==============================] - 15s 31ms/step - loss: 2.2220 - accuracy: 0.5338
# Epoch 16/100
# 484/484 [==============================] - 14s 29ms/step - loss: 2.0089 - accuracy: 0.5783
# Epoch 17/100
# 484/484 [==============================] - 14s 30ms/step - loss: 1.8225 - accuracy: 0.6174
# Epoch 18/100
# 484/484 [==============================] - 15s 30ms/step - loss: 1.6519 - accuracy: 0.6561
# Epoch 19/100
# 484/484 [==============================] - 15s 32ms/step - loss: 1.5093 - accuracy: 0.6887
# Epoch 20/100
# 484/484 [==============================] - 14s 29ms/step - loss: 1.3758 - accuracy: 0.7182
# Epoch 21/100
# 484/484 [==============================] - 14s 29ms/step - loss: 1.2560 - accuracy: 0.7420
# Epoch 22/100
# 484/484 [==============================] - 15s 31ms/step - loss: 1.1589 - accuracy: 0.7652
# Epoch 23/100
# 484/484 [==============================] - 15s 32ms/step - loss: 1.0677 - accuracy: 0.7812
# Epoch 24/100
# 484/484 [==============================] - 16s 33ms/step - loss: 0.9904 - accuracy: 0.7955
# Epoch 25/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.9300 - accuracy: 0.8042
# Epoch 26/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.8749 - accuracy: 0.8139
# Epoch 27/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.8238 - accuracy: 0.8237
# Epoch 28/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.7842 - accuracy: 0.8305
# Epoch 29/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.7514 - accuracy: 0.8331
# Epoch 30/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.7264 - accuracy: 0.8381
# Epoch 31/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.7031 - accuracy: 0.8389
# Epoch 32/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.6819 - accuracy: 0.8396
# Epoch 33/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.6618 - accuracy: 0.8425
# Epoch 34/100
# 484/484 [==============================] - 15s 32ms/step - loss: 0.6562 - accuracy: 0.8443
# Epoch 35/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.6436 - accuracy: 0.8432
# Epoch 36/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.6305 - accuracy: 0.8451
# Epoch 37/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.6193 - accuracy: 0.8466
# Epoch 38/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.6063 - accuracy: 0.8490
# Epoch 39/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.6058 - accuracy: 0.8476
# Epoch 40/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5954 - accuracy: 0.8485
# Epoch 41/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5908 - accuracy: 0.8489
# Epoch 42/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.5878 - accuracy: 0.8493
# Epoch 43/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5851 - accuracy: 0.8491
# Epoch 44/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5781 - accuracy: 0.8485
# Epoch 45/100
# 484/484 [==============================] - 15s 32ms/step - loss: 0.5793 - accuracy: 0.8490
# Epoch 46/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.5730 - accuracy: 0.8496
# Epoch 47/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.5714 - accuracy: 0.8485
# Epoch 48/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5690 - accuracy: 0.8490
# Epoch 49/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.5642 - accuracy: 0.8487
# Epoch 50/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.5581 - accuracy: 0.8486
# Epoch 51/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5571 - accuracy: 0.8490
# Epoch 52/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.5600 - accuracy: 0.8494
# Epoch 53/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.5585 - accuracy: 0.8489
# Epoch 54/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.5543 - accuracy: 0.8485
# Epoch 55/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5552 - accuracy: 0.8485
# Epoch 56/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.5475 - accuracy: 0.8490
# Epoch 57/100
# 484/484 [==============================] - 16s 33ms/step - loss: 0.5443 - accuracy: 0.8493
# Epoch 58/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.5455 - accuracy: 0.8496
# Epoch 59/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5455 - accuracy: 0.8503
# Epoch 60/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.5511 - accuracy: 0.8490
# Epoch 61/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.5503 - accuracy: 0.8489
# Epoch 62/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.5412 - accuracy: 0.8489
# Epoch 63/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.5342 - accuracy: 0.8510
# Epoch 64/100
# 484/484 [==============================] - 15s 32ms/step - loss: 0.5349 - accuracy: 0.8499
# Epoch 65/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.5323 - accuracy: 0.8500
# Epoch 66/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.5335 - accuracy: 0.8503
# Epoch 67/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.5346 - accuracy: 0.8487
# Epoch 68/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.5349 - accuracy: 0.8498
# Epoch 69/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5331 - accuracy: 0.8486
# Epoch 70/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.5284 - accuracy: 0.8506
# Epoch 71/100
# 484/484 [==============================] - 15s 32ms/step - loss: 0.5287 - accuracy: 0.8501
# Epoch 72/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.5269 - accuracy: 0.8507
# Epoch 73/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.5266 - accuracy: 0.8494
# Epoch 74/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5331 - accuracy: 0.8491
# Epoch 75/100
# 484/484 [==============================] - 15s 32ms/step - loss: 0.5335 - accuracy: 0.8485
# Epoch 76/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5236 - accuracy: 0.8507
# Epoch 77/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.5180 - accuracy: 0.8509
# Epoch 78/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5188 - accuracy: 0.8505
# Epoch 79/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.5173 - accuracy: 0.8507
# Epoch 80/100
# 484/484 [==============================] - 15s 31ms/step - loss: 0.5193 - accuracy: 0.8505
# Epoch 81/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.5176 - accuracy: 0.8494
# Epoch 82/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.5182 - accuracy: 0.8498
# Epoch 83/100
# 484/484 [==============================] - 15s 32ms/step - loss: 0.5185 - accuracy: 0.8504
# Epoch 84/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.5172 - accuracy: 0.8506
# Epoch 85/100
# 484/484 [==============================] - 13s 28ms/step - loss: 0.5155 - accuracy: 0.8504
# Epoch 86/100
# 484/484 [==============================] - 14s 28ms/step - loss: 0.5148 - accuracy: 0.8515
# Epoch 87/100
# 484/484 [==============================] - 13s 28ms/step - loss: 0.5155 - accuracy: 0.8493
# Epoch 88/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.5298 - accuracy: 0.8459
# Epoch 89/100
# 484/484 [==============================] - 13s 28ms/step - loss: 0.5450 - accuracy: 0.8428
# Epoch 90/100
# 484/484 [==============================] - 14s 28ms/step - loss: 0.5114 - accuracy: 0.8495
# Epoch 91/100
# 484/484 [==============================] - 14s 28ms/step - loss: 0.5035 - accuracy: 0.8516
# Epoch 92/100
# 484/484 [==============================] - 15s 30ms/step - loss: 0.5039 - accuracy: 0.8503
# Epoch 93/100
# 484/484 [==============================] - 14s 30ms/step - loss: 0.5057 - accuracy: 0.8511
# Epoch 94/100
# 484/484 [==============================] - 14s 28ms/step - loss: 0.5083 - accuracy: 0.8505
# Epoch 95/100
# 484/484 [==============================] - 13s 28ms/step - loss: 0.5063 - accuracy: 0.8512
# Epoch 96/100
# 484/484 [==============================] - 13s 28ms/step - loss: 0.5056 - accuracy: 0.8514
# Epoch 97/100
# 484/484 [==============================] - 13s 27ms/step - loss: 0.5059 - accuracy: 0.8507
# Epoch 98/100
# 484/484 [==============================] - 13s 28ms/step - loss: 0.5067 - accuracy: 0.8513
# Epoch 99/100
# 484/484 [==============================] - 14s 29ms/step - loss: 0.5046 - accuracy: 0.8507
# Epoch 100/100
# 484/484 [==============================] - 13s 28ms/step - loss: 0.5050 - accuracy: 0.8511

# %%
# Take a look at the training curves of your model

acc = history.history['accuracy']
loss = history.history['loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.title('Training accuracy')

plt.figure()

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.title('Training loss')
plt.legend()

plt.show()

# %%
# def download_history():
#   import pickle
#   from google.colab import files

#   with open('history.pkl', 'wb') as f:
#     pickle.dump(history.history, f)

#   files.download('history.pkl')

# download_history()

# %%
seed_text = "Rizky Ganteng"
next_words = 100

for _ in range(next_words):
    # Convert the text into sequences
    token_list = tokenizer.texts_to_sequences([seed_text])[0]
    # Pad the sequences
    token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
    # Get the probabilities of predicting a word
    predicted = model.predict(token_list, verbose=0)
    # Choose the next word based on the maximum probability
    predicted = np.argmax(predicted, axis=-1).item()
    # Get the actual word from the word index
    output_word = tokenizer.index_word[predicted]
    # Append to the current text
    seed_text += " " + output_word

print(seed_text)
# Out:
# Rizky Ganteng with eager compounds we our palate urge be gone spirit now fingers the face of thine eyes you so rare repair be part all me those more lies treasure thee behold me cheeks heart more one more part of me untrue this sin and thine more more part of me be forth you so thine eyes one more of those parts that thee doth dwell boy ' in my mind eyes with mine eye is wide mother's consent anchor'd say more one strong truth and this and heart you green those be rage and die in me muse more thief

# %%
model.save("/content/drive/MyDrive/Search Recommendation/Search Recommendation.h5")

# %%
# # Download metadata checker
# !wget -nc https://storage.googleapis.com/tensorflow-1-public/colab_metadata_checker.py

# %%
# import colab_metadata_checker

# # Please see the output of this cell to see which file you need to submit to the grader
# colab_metadata_checker.run('C3W4_Assignment_fixed.ipynb')
